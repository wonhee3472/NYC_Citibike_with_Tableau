# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
citi_bike_df = pd.read_csv('../../Documents/My Tableau Repository/Datasources/2021.4/en_US-US/201908-citibike-tripdata.csv')

# %%
# 2. Check the datatypes of your columns. 
citi_bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2344224 entries, 0 to 2344223
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         float64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           float64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 268.3+ MB

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
citi_bike_df['tripduration'] = pd.to_datetime(citi_bike_df['tripduration'], unit='s')

# %%
# 4. Check the datatypes of your columns. 
citi_bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2344224 entries, 0 to 2344223
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             datetime64[ns]
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         float64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           float64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(5)
# memory usage: 268.3+ MB

# %%
citi_bike_df.sample(5)
# Out:
#                tripduration                 starttime  \
# 265558  1970-01-01 00:12:26  2019-08-04 12:26:38.1160
# 2277691 1970-01-01 00:06:20  2019-08-30 22:32:30.1460
# 92331   1970-01-01 00:11:32  2019-08-02 07:00:58.4720
# 1791265 1970-01-01 00:03:56  2019-08-24 16:12:14.8420
# 992252  1970-01-01 00:02:38  2019-08-13 19:39:48.2240
#
#                          stoptime  start station id  \
# 265558   2019-08-04 12:39:04.9620            3137.0
# 2277691  2019-08-30 22:38:50.2640             432.0
# 92331    2019-08-02 07:12:31.0850            3553.0
# 1791265  2019-08-24 16:16:11.1650            3778.0
# 992252   2019-08-13 19:42:26.3520             476.0
#
#                          start station name  start station latitude  \
# 265558                      5 Ave & E 73 St               40.772828
# 2277691                   E 7 St & Avenue A               40.726218
# 92331    Frederick Douglass Blvd & W 112 St               40.801694
# ...

# %%
# 5. Export the Dataframe as a new CSV file without the index.
citi_bike_df.to_csv('201908-citibike-tripdata.csv', index=False)

# %%
pd.read_csv('201908-citibike-tripdata.csv').sample(5)
# Out:
#                 tripduration                 starttime  \
# 1001432  1970-01-01 00:13:06  2019-08-13 22:25:40.1680
# 539022   1970-01-01 00:25:45  2019-08-08 07:52:33.8290
# 163810   1970-01-01 00:02:26  2019-08-02 21:05:29.8800
# 780728   1970-01-01 00:25:51  2019-08-11 09:12:28.1010
# 871546   1970-01-01 00:07:46  2019-08-12 11:29:43.5770
#
#                          stoptime  start station id  \
# 1001432  2019-08-13 22:38:46.5550             311.0
# 539022   2019-08-08 08:18:19.5100            3046.0
# 163810   2019-08-02 21:07:56.5340             368.0
# 780728   2019-08-11 09:38:20.0240             476.0
# 871546   2019-08-12 11:37:30.3640             305.0
#
#                     start station name  start station latitude  \
# 1001432         Norfolk St & Broome St               40.717227
# 539022   Marcus Garvey Blvd & Macon St               40.682601
# 163810              Carmine St & 6 Ave               40.730386
# ...
